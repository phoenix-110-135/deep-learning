# %%
pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in c:\users\ali\appdata\local\programs\python\python313\lib\site-packages (2.1.3)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas
#   Downloading pandas-3.0.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ali\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ali\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-3.0.1-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.7 MB 2.2 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.7 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.7 MB 3.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.7 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 3.8 MB/s eta 0:00:00
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-3.0.1 tzdata-2025.3

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
data = pd.read_csv('cardio_train1.csv')

# %%
data['age'] = data['age'] // 365

# %%
data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   51       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   47       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
X = data.iloc[:, 1:-1]
y = data.iloc[:, -1]

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X = mms.fit_transform(X)

# %%
X
# Out:
# array([[0.6       , 1.        , 0.57948718, ..., 0.        , 0.        ,
#         1.        ],
#        [0.74285714, 0.        , 0.51794872, ..., 0.        , 0.        ,
#         1.        ],
#        [0.62857143, 0.        , 0.56410256, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.65714286, 1.        , 0.65641026, ..., 0.        , 1.        ,
#         0.        ],
#        [0.91428571, 0.        , 0.55384615, ..., 0.        , 0.        ,
#         0.        ],
#        [0.77142857, 0.        , 0.58974359, ..., 0.        , 0.        ,
#         1.        ]])

# %%
np.shape(X)
# Out:
# (70000, 11)

# %%
y = pd.get_dummies(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33123)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(11, activation='relu', input_shape=(11,)),
    tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
# Out:
# c:\Users\Ali\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            62 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 554 (2.16 KB)
#  Trainable params: 554 (2.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_layer_activations=True, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), batch_size=100)
# Out:
# Epoch 1/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - categorical_accuracy: 0.5936 - loss: 0.6595 - val_categorical_accuracy: 0.6314 - val_loss: 0.6416
# Epoch 2/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - categorical_accuracy: 0.6387 - loss: 0.6345 - val_categorical_accuracy: 0.6360 - val_loss: 0.6365
# Epoch 3/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - categorical_accuracy: 0.6419 - loss: 0.6311 - val_categorical_accuracy: 0.6376 - val_loss: 0.6350
# Epoch 4/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - categorical_accuracy: 0.6435 - loss: 0.6292 - val_categorical_accuracy: 0.6426 - val_loss: 0.6318
# Epoch 5/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - categorical_accuracy: 0.6454 - loss: 0.6279 - val_categorical_accuracy: 0.6381 - val_loss: 0.6341
# Epoch 6/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - categorical_accuracy: 0.6480 - loss: 0.6269 - val_categorical_accuracy: 0.6423 - val_loss: 0.6303
# Epoch 7/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - categorical_accuracy: 0.6478 - loss: 0.6267 - val_categorical_accuracy: 0.6458 - val_loss: 0.6291
# Epoch 8/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - categorical_accuracy: 0.6492 - loss: 0.6254 - val_categorical_accuracy: 0.6445 - val_loss: 0.6282
# Epoch 9/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - categorical_accuracy: 0.6490 - loss: 0.6256 - val_categorical_accuracy: 0.6473 - val_loss: 0.6274
# Epoch 10/10
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - categorical_accuracy: 0.6505 - loss: 0.6246 - val_categorical_accuracy: 0.6457 - val_loss: 0.6271

# %%
from sklearn.ensemble import RandomForestClassifier
yr = data.iloc[:, -1]

# %%
np.unique(yr, return_counts=True)
# Out:
# (array([0, 1]), array([35021, 34979]))

# %%
rfc = RandomForestClassifier(n_estimators=200)
Xr_train, Xr_test, yr_train, yr_test = train_test_split(X, yr, random_state=33123)

# %%
rfc.fit(Xr_train, yr_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
from sklearn.metrics import classification_report

# %%
y_pred = rfc.predict(Xr_test)
print(classification_report(y_true=yr_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.71      8652
#            1       0.71      0.71      0.71      8848
#
#     accuracy                           0.71     17500
#    macro avg       0.71      0.71      0.71     17500
# weighted avg       0.71      0.71      0.71     17500

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(11, activation='relu', input_shape=(11,)),
    tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(25, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])
# Out:
# c:\Users\Ali\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 60)             │         1,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 25)             │         1,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            52 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,929 (15.35 KB)
#  Trainable params: 3,929 (15.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=100)
# Out:
# Epoch 1/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6215 - loss: 0.6487 - val_categorical_accuracy: 0.6289 - val_loss: 0.6406
# Epoch 2/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - categorical_accuracy: 0.6373 - loss: 0.6342 - val_categorical_accuracy: 0.6377 - val_loss: 0.6357
# Epoch 3/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - categorical_accuracy: 0.6413 - loss: 0.6308 - val_categorical_accuracy: 0.6429 - val_loss: 0.6323
# Epoch 4/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.6452 - loss: 0.6288 - val_categorical_accuracy: 0.6407 - val_loss: 0.6325
# Epoch 5/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - categorical_accuracy: 0.6472 - loss: 0.6273 - val_categorical_accuracy: 0.6326 - val_loss: 0.6424
# Epoch 6/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.6473 - loss: 0.6266 - val_categorical_accuracy: 0.6449 - val_loss: 0.6284
# Epoch 7/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6492 - loss: 0.6251 - val_categorical_accuracy: 0.6458 - val_loss: 0.6279
# Epoch 8/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - categorical_accuracy: 0.6488 - loss: 0.6248 - val_categorical_accuracy: 0.6426 - val_loss: 0.6319
# Epoch 9/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6499 - loss: 0.6248 - val_categorical_accuracy: 0.6467 - val_loss: 0.6267
# Epoch 10/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - categorical_accuracy: 0.6503 - loss: 0.6232 - val_categorical_accuracy: 0.6465 - val_loss: 0.6268
# Epoch 11/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6498 - loss: 0.6229 - val_categorical_accuracy: 0.6453 - val_loss: 0.6275
# Epoch 12/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - categorical_accuracy: 0.6510 - loss: 0.6225 - val_categorical_accuracy: 0.6477 - val_loss: 0.6248
# Epoch 13/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6518 - loss: 0.6217 - val_categorical_accuracy: 0.6494 - val_loss: 0.6247
# Epoch 14/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6528 - loss: 0.6224 - val_categorical_accuracy: 0.6486 - val_loss: 0.6249
# Epoch 15/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6536 - loss: 0.6211 - val_categorical_accuracy: 0.6457 - val_loss: 0.6268
# Epoch 16/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - categorical_accuracy: 0.6546 - loss: 0.6208 - val_categorical_accuracy: 0.6497 - val_loss: 0.6236
# Epoch 17/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.6529 - loss: 0.6205 - val_categorical_accuracy: 0.6411 - val_loss: 0.6300
# Epoch 18/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - categorical_accuracy: 0.6547 - loss: 0.6196 - val_categorical_accuracy: 0.6474 - val_loss: 0.6241
# Epoch 19/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.6541 - loss: 0.6190 - val_categorical_accuracy: 0.6514 - val_loss: 0.6231
# Epoch 20/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6553 - loss: 0.6189 - val_categorical_accuracy: 0.6526 - val_loss: 0.6231
# Epoch 21/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6570 - loss: 0.6177 - val_categorical_accuracy: 0.6517 - val_loss: 0.6210
# Epoch 22/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - categorical_accuracy: 0.6569 - loss: 0.6169 - val_categorical_accuracy: 0.6547 - val_loss: 0.6197
# Epoch 23/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - categorical_accuracy: 0.6591 - loss: 0.6157 - val_categorical_accuracy: 0.6552 - val_loss: 0.6203
# Epoch 24/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - categorical_accuracy: 0.6603 - loss: 0.6147 - val_categorical_accuracy: 0.6590 - val_loss: 0.6193
# Epoch 25/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - categorical_accuracy: 0.6623 - loss: 0.6130 - val_categorical_accuracy: 0.6589 - val_loss: 0.6175
# Epoch 26/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.6607 - loss: 0.6126 - val_categorical_accuracy: 0.6642 - val_loss: 0.6124
# Epoch 27/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6658 - loss: 0.6109 - val_categorical_accuracy: 0.6616 - val_loss: 0.6128
# Epoch 28/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - categorical_accuracy: 0.6695 - loss: 0.6079 - val_categorical_accuracy: 0.6674 - val_loss: 0.6104
# Epoch 29/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6748 - loss: 0.6036 - val_categorical_accuracy: 0.6806 - val_loss: 0.6018
# Epoch 30/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - categorical_accuracy: 0.6784 - loss: 0.5992 - val_categorical_accuracy: 0.6860 - val_loss: 0.5969
# Epoch 31/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6873 - loss: 0.5931 - val_categorical_accuracy: 0.6817 - val_loss: 0.6010
# Epoch 32/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.6908 - loss: 0.5893 - val_categorical_accuracy: 0.6950 - val_loss: 0.5879
# Epoch 33/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - categorical_accuracy: 0.6936 - loss: 0.5874 - val_categorical_accuracy: 0.6851 - val_loss: 0.5961
# Epoch 34/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.6985 - loss: 0.5820 - val_categorical_accuracy: 0.6969 - val_loss: 0.5837
# Epoch 35/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7005 - loss: 0.5810 - val_categorical_accuracy: 0.7069 - val_loss: 0.5787
# Epoch 36/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7034 - loss: 0.5764 - val_categorical_accuracy: 0.7091 - val_loss: 0.5780
# Epoch 37/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.7004 - loss: 0.5775 - val_categorical_accuracy: 0.7078 - val_loss: 0.5762
# Epoch 38/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - categorical_accuracy: 0.7053 - loss: 0.5752 - val_categorical_accuracy: 0.7164 - val_loss: 0.5695
# Epoch 39/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7069 - loss: 0.5731 - val_categorical_accuracy: 0.6677 - val_loss: 0.6002
# Epoch 40/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7091 - loss: 0.5711 - val_categorical_accuracy: 0.7134 - val_loss: 0.5708
# Epoch 41/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7085 - loss: 0.5721 - val_categorical_accuracy: 0.7195 - val_loss: 0.5673
# Epoch 42/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.7122 - loss: 0.5685 - val_categorical_accuracy: 0.6899 - val_loss: 0.5865
# Epoch 43/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.7100 - loss: 0.5696 - val_categorical_accuracy: 0.6914 - val_loss: 0.5935
# Epoch 44/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7155 - loss: 0.5657 - val_categorical_accuracy: 0.7002 - val_loss: 0.5760
# Epoch 45/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - categorical_accuracy: 0.7106 - loss: 0.5695 - val_categorical_accuracy: 0.7118 - val_loss: 0.5707
# Epoch 46/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7167 - loss: 0.5638 - val_categorical_accuracy: 0.7111 - val_loss: 0.5702
# Epoch 47/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - categorical_accuracy: 0.7155 - loss: 0.5651 - val_categorical_accuracy: 0.7070 - val_loss: 0.5793
# Epoch 48/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - categorical_accuracy: 0.7146 - loss: 0.5648 - val_categorical_accuracy: 0.7149 - val_loss: 0.5654
# Epoch 49/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - categorical_accuracy: 0.7140 - loss: 0.5648 - val_categorical_accuracy: 0.7174 - val_loss: 0.5648
# Epoch 50/50
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - categorical_accuracy: 0.7189 - loss: 0.5621 - val_categorical_accuracy: 0.7166 - val_loss: 0.5644

# %%
model.predict(X_test)[3]
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# array([0.2597197 , 0.74028033], dtype=float32)

# %%
np.argmax(model.predict(X_test)[3])
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# np.int64(1)

# %%
y_pred = np.argmax(model.predict(Xr_test), axis=1)
print(classification_report(y_true=yr_test, y_pred=y_pred))
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.71      8652
#            1       0.71      0.74      0.73      8848
#
#     accuracy                           0.72     17500
#    macro avg       0.72      0.72      0.72     17500
# weighted avg       0.72      0.72      0.72     17500

# %%
# MasoudKaviani.ir
